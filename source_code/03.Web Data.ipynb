# %% [markdown]
# # 03. Web Data

# %% [markdown]
# [1. BeautifulSoup for web data](#Beautifulsoup) <br>
# &emsp;    [- BeautifulSoup Basic](#beautifulsoup-basic) <br>
# &emsp;    [- BeautifulSoup 예제 1-1(urllib.request, find, find_all)](#beautifulsoup1-1) <br>
# &emsp;    [- BeautifulSoup 예제 1-2(requests, select_one, select)](#beautifulsoup1-2) <br>
# &emsp;    [- BeautifulSoup 예제 2(위키백과 여명의 눈동자 - 주요인물)](#위키백과) <br>
# [Python List 데이터형](#list) <br>
# &emsp;    [- list.copy()](#copy) <br>
# &emsp;    [- list.extend()](#extend) <br>
# &emsp;    [- list.remove()](#remove) <br>
# &emsp;    [- isinstance()](#isinstance) <br>
# [2. 시카고 맛집 데이터 분석 - 개요](#개요) <br>
# [3. 시카고 맛집 데이터 분석 - 메인페이지](#메인페이지) <br>
# &emsp;    [- 페이지 연결해서 html 가져오기](#html) <br>
# &emsp;    [- 식당 50개 정보 추출](#restaurants-50-list) <br>
# [4. 시카고 맛집 데이터 분석 - 하위페이지](#하위) <br>
# &emsp;    [- rank 1 식당 하위 페이지 html 가져오기](#rank1-하위) <br>
# &emsp;    [- 50개의 식당 하위 페이지에서 식당 정보 수집](#하위페이지s) <br>
# [정규표현식 예제](#정규표현식) <br>
# [5. 시카고 맛집 데이터 지도 시각화](#folium) <br>
#
#
# [Github에서는 toc가 작동안함. nbviewer로 보기👀](https://nbviewer.org/github/solpinetree/ds_study/blob/main/source_code/03.Web%20Data.ipynb)

# %% [markdown]
# <a id="Beautifulsoup"></a>
# ## 1. BeautifulSoup for web data
#
# ---

# %% [markdown]
# <a id="beautifulsoup-basic"></a>
# ### BeautifulSoup Basic
# - install
# ```
# conda install anaconda::beautifulsoup4 <br>
# pip install beautifulsoup4
# ```
#
# - data
#     - 03.test_first.html 을 가지고 실습

# %%
from bs4 import BeautifulSoup

# %%
page = open("../data/03. test_first.html", "r").read()
soup = BeautifulSoup(page, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Very Simple HTML Code by PinkWink
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happy PinkWink.
#     <a href="http://www.pinkwink.kr" id="pw-link">
#      PinkWink
#     </a>
#    </p>
#    <p class="inner-text second-item">
#     Happy Data Science.
#     <a href="https://www.python.org" id="py-link">
#      Python
#     </a>
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     Data Science is funny.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     All I need is Love.
#    </b>
#   </p>
#  </body>
# </html>

# %%
# head 태그 조회
soup.head
# Out:
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>

# %%
# body 태그 조회
soup.body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %% [markdown]
# #### find()
#
# 파이썬 예약어
# - class, id, def, list, str, int, tuple ...

# %%
# p 태그 조회
# 처음 발견한 P 태그만 출력
# find()
soup.p
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
soup.find("p")
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
soup.find("p", class_="inner-text first-item")
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
soup.find("p", {'class':"outer-text first-item"})
# Out:
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>

# %%
soup.find("p", {'class':"outer-text first-item"}).text
# Out:
# '\n\n                Data Science is funny.\n            \n'

# %%
soup.find("p", {'class':"outer-text first-item"}).text.strip()
# Out:
# 'Data Science is funny.'

# %%
# 다중 조건

soup.find("p", {"class":"inner-text first-item", "id":"first"})
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %% [markdown]
# #### find_all()
# 여러 개의 태그를 리스트 형태로 반환

# %%
soup.find_all("p")
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>,
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>,
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
# 특정 태그 확인
soup.find_all(class_="outer-text")
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find_all(id="pw-link")
# Out:
# [<a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>]

# %%
soup.find_all(id="pw-link")[0].text
# Out:
# 'PinkWink'

# %%
soup.find_all("p", class_="inner-text second-item")
# Out:
# [<p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>]

# %%
len(soup.find_all("p"))
# Out:
# 4

# %%
print(soup.find_all("p")[0].text)
print(soup.find_all("p")[0].string) # <p> 태그 내에 자식이 있으면 None 을 출력
print(soup.find_all("p")[1].get_text())
# Out:
#                 Happy PinkWink.
#                 PinkWink
#
# None
#
#                 Happy Data Science.
#                 Python

# %%
# p 태그 리스트에서 텍스트 속성만 출력

[each_tag.text for each_tag in soup.find_all("p")]
# Out:
# ['\n                Happy PinkWink.\n                PinkWink\n',
#  '\n                Happy Data Science.\n                Python\n',
#  '\n\n                Data Science is funny.\n            \n',
#  '\n\n                All I need is Love.\n            \n']

# %% [markdown]
# #### get()

# %%
# a 태그에서 href 속성값에 있는 값 추출

links =  [tags.get("href") for tags in soup.find_all("a")]
links
# Out:
# ['http://www.pinkwink.kr', 'https://www.python.org']

# %%
a_tags = soup.find_all("a")

for each in a_tags:
    href = each.get("href") # each["href"]
    text = each.get_text()
    print(text + " => " + href)
# Out:
# PinkWink => http://www.pinkwink.kr
# Python => https://www.python.org

# %% [markdown]
# <a id="beautifulsoup1-1"></a>
# ### BeautifulSoup 에제 1-1 네이버 금융(urllib.request, find, find_all)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "https://finance.naver.com/marketindex/"
response = urlopen(url)
response.status
# Out:
# 200

# %%
url = "https://finance.naver.com/marketindex/"
page = urlopen(url)
soup = BeautifulSoup(page, "html.parser")
print(soup.prettify())
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240725112316/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240725112316/js/jindo.1.5.3.element-text-patch.js" type="text/javascript">
# </script>
# <div id="container" style="padding-bottom:0px;">
#  <div class="market_include">
#   <div class="market_data">
#    <div class="market1">
#     <div class="title">
#      <h2 class="h_market1">
#       <span>
#        ШЏРќ АэНУ ШЏРВ
#       </span>
#      </h2>
#     </div>
#     <!-- data -->
#     <div class="data">
#      <ul class="data_lst" id="exchangeList">
#       <li class="on">
#        <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# ...

# %%
soup.find_all("span", class_="value")
# Out:
# [<span class="value">1,361.50</span>,
#  <span class="value">929.22</span>,
#  <span class="value">1,485.46</span>,
#  <span class="value">190.02</span>,
#  <span class="value">146.6800</span>,
#  <span class="value">1.0921</span>,
#  <span class="value">1.2805</span>,
#  <span class="value">102.9800</span>,
#  <span class="value">73.52</span>,
#  <span class="value">1708.98</span>,
#  <span class="value">2469.8</span>,
#  <span class="value">106358.61</span>]

# %%
soup.find_all("span", {"class":"value"})
# Out:
# [<span class="value">1,361.50</span>,
#  <span class="value">929.22</span>,
#  <span class="value">1,485.46</span>,
#  <span class="value">190.02</span>,
#  <span class="value">146.6800</span>,
#  <span class="value">1.0921</span>,
#  <span class="value">1.2805</span>,
#  <span class="value">102.9800</span>,
#  <span class="value">73.52</span>,
#  <span class="value">1708.98</span>,
#  <span class="value">2469.8</span>,
#  <span class="value">106358.61</span>]

# %%
soup.find_all("span", class_="value")[0].text, soup.find_all("span", class_="value")[0].string, soup.find_all("span", class_="value")[0].get_text()
# Out:
# ('1,361.50', '1,361.50', '1,361.50')

# %% [markdown]
# <a id="beautifulsoup1-2"></a>
# ### BeautifulSoup 예제 1-2 네이버 금융(requests, select_one, select)
# - pip install requests
#     - 설치 확인 : pip list | grep requests
# - select, select_one
# - find, select_one : 단일 선택
# - find_all, select : 다중 선택

# %%
import requests
# from urllib.request.Request
from bs4 import BeautifulSoup

# %%
url = "https://finance.naver.com/marketindex/"
response = requests.get(url)
# request.get(), request.post()
# response.text, response.content 에도 html 이 담겨있음. 좀 더 편하게 보기 위해 BeautifulSoup 으로 본다.
soup = BeautifulSoup(response.text, "html.parser")
print(soup.prettify())
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240725112316/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240725112316/js/jindo.1.5.3.element-text-patch.js" type="text/javascript">
# </script>
# <div id="container" style="padding-bottom:0px;">
#  <div class="market_include">
#   <div class="market_data">
#    <div class="market1">
#     <div class="title">
#      <h2 class="h_market1">
#       <span>
#        환전 고시 환율
#       </span>
#      </h2>
#     </div>
#     <!-- data -->
#     <div class="data">
#      <ul class="data_lst" id="exchangeList">
#       <li class="on">
#        <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# ...

# %%
exchangeList = soup.select("#exchangeList > li")
exchangeList
# Out:
# [<li class="on">
#  <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
#  <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
#  <div class="head_info point_dn">
#  <span class="value">1,361.50</span>
#  <span class="txt_krw"><span class="blind">원</span></span>
#  <span class="change"> 9.50</span>
#  <span class="blind">하락</span>
#  </div>
#  </a>
#  <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdc', '', '', event);">
#  <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDKRW.png" width="295"/>
#  </a>
#  <div class="graph_info">
#  <span class="time">2024.08.02 23:50</span>
#  <span class="source">하나은행 기준</span>
#  <span class="count">고시회차<span class="num">665</span>회</span>
#  </div>
#  </li>,
#  <li class="">
# ...

# %%
title = exchangeList[0].select_one(".h_lst").text
exchange = exchangeList[0].select_one(".value").text
change = exchangeList[0].select_one(".change").text
updown = exchangeList[0].select_one("div.head_info > .blind").text

baseUrl = "https://finance.naver.com"

link = baseUrl + exchangeList[0].select_one("a")["href"]

title, exchange, change, updown, link
# Out:
# ('미국 USD',
#  '1,361.50',
#  ' 9.50',
#  '하락',
#  'https://finance.naver.com/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW')

# %% [markdown]
# #### 4개 데이터 수집

# %%
import pandas as pd

# %%
exchange_datas= []
baseUrl = "https://finance.naver.com"

for item in exchangeList:
    data = {
        "title": item.select_one(".h_lst").text,
        "exchange": item.select_one(".value").text,
        "change": item.select_one(".change").text,
        "updown": item.select_one("div.head_info > .blind").text,
        "link": baseUrl + item.select_one("a")["href"]
    }
    exchange_datas.append(data)

df = pd.DataFrame(exchange_datas)
df.to_excel("./naverfinance.xlsx")

# %% [markdown]
# <a id="위키백과"></a>
# ### BeautifulSoup 예제2 위키백과 문서 정보 가져오기

# %%
import urllib
from urllib.request import urlopen, Request

html = "https://ko.wikipedia.org/wiki/{search_words}"
req = Request(html.format(search_words=urllib.parse.quote("여명의_눈동자")))
response = urlopen(req)
soup = BeautifulSoup(response, "html.parser")
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <title>여명의 눈동자 - 위키백과, 우리 모두의 백과사전</title>
# ...

# %%
mainActorsLi = soup.find(id="주요_인물").parent.find_next_sibling("ul").find_all("li")
mainActorsLi
# Out:
# [<li><a href="/wiki/%EC%B1%84%EC%8B%9C%EB%9D%BC" title="채시라">채시라</a> : 윤여옥 역 (아역: <a href="/wiki/%EA%B9%80%EB%AF%BC%EC%A0%95_(1982%EB%85%84)" title="김민정 (1982년)">김민정</a>)</li>,
#  <li><a href="/wiki/%EB%B0%95%EC%83%81%EC%9B%90" title="박상원">박상원</a> : 장하림(하리모토 나츠오) 역 (아역: <a href="/wiki/%EA%B9%80%ED%83%9C%EC%A7%84_(%EC%88%98%ED%95%84%EA%B0%80)" title="김태진 (수필가)">김태진</a>)</li>,
#  <li><a href="/wiki/%EC%B5%9C%EC%9E%AC%EC%84%B1_(%EB%B0%B0%EC%9A%B0)" title="최재성 (배우)">최재성</a> : 최대치(사카이) 역 (아역: <a href="/wiki/%EC%9E%A5%EB%8D%95%EC%88%98_(%EB%B0%B0%EC%9A%B0)" title="장덕수 (배우)">장덕수</a>)</li>]

# %%
mainActors = []

for li in mainActorsLi:
    mainActors.append(li.find("a").text)

mainActors
# Out:
# ['채시라', '박상원', '최재성']

# %% [markdown]
# ---

# %% [markdown]
# <a id="list"></a>
# ## Python List 데이터형
# - list 형은 대괄호로 생성

# %% [markdown]
# <a id="copy"></a>
# ### list.copy()

# %%
colors = ["red", "blue", "green"]

colors[0], colors[1], colors[2]
# Out:
# ('red', 'blue', 'green')

# %%
b = colors
b
# Out:
# ['red', 'blue', 'green']

# %%
b[1] = "black"
b
# Out:
# ['red', 'black', 'green']

# %%
colors
# Out:
# ['red', 'black', 'green']

# %%
c = colors.copy()
c[1] = "pink"
c, colors
# Out:
# (['red', 'pink', 'green'], ['red', 'black', 'green'])

# %% [markdown]
# <a id="extend"></a>
# ### list.extend()
# - 제일 뒤에 자료 추가

# %%
colors.extend(["pink", "purple", "orange"])
colors
# Out:
# ['red', 'black', 'green', 'pink', 'purple', 'orange']

# %%
colors.extend(["orange"])

# %%
colors
# Out:
# ['red', 'black', 'green', 'pink', 'purple', 'orange', 'orange']

# %% [markdown]
# <a id="remove"></a>
# ### list.remove()
# - 자료를 삭제

# %%
colors.remove("orange")
colors
# Out:
# ['red', 'black', 'green', 'pink', 'purple', 'orange']

# %% [markdown]
# <a id="isinstance"></a>
# ### isinstance()

# %%
isinstance(colors, list), isinstance(colors, str), isinstance(colors, int)
# Out:
# (True, False, False)

# %% [markdown]
# ---

# %% [markdown]
# <a id="개요"></a>
# ## 2. 시카고 맛집 데이터 분석 - 개요
# - https://www.chicagomag.com/chicago-magazine/august-2024/chicagos-50-best-restaurants-ranked/
#   - 검색어 : `chicago magazine the 50 best`
#
# ```
# 최종목표
# 총 51개 페이지에서 각 가게의 정보를 가져온다
# - 가게이름
# - 대표메뉴
# - 대표메뉴의 가격
# - 가게주소
# ```

# %% [markdown]
# ---

# %% [markdown]
# <a id="메인페이지"></a>
# ## 3. 시카고 맛집 데이터 분석 - 메인페이지

# %% [markdown]
# <a id="html"></a>
# ### 페이지 연결해서 html 가져오기

# %%
## fake-useragnet 사용 x

from urllib.request import Request, urlopen
from bs4 import BeautifulSoup

url_base = "https://www.chicagomag.com/"
url_sub = "chicago-magazine/august-2024/chicagos-50-best-restaurants-ranked/"
url = url_base + url_sub

req = Request(url, headers={"User-Agent": "Chrome"})
response = urlopen(req)
response.status
# Out:
# 200

# %%
## fake-useragent 사용 o
## !pip install fake-useragent

from urllib.request import Request, urlopen
from fake_useragent import UserAgent
from bs4 import BeautifulSoup

url_base = "https://www.chicagomag.com/"
url_sub = "chicago-magazine/august-2024/chicagos-50-best-restaurants-ranked/"
url = url_base + url_sub

ua = UserAgent()
req = Request(url, headers={"User-Agent": ua.ie})
html = urlopen(req)
soup = BeautifulSoup(html, "html.parser")
print(soup.prettify())
# Out:
# Error occurred during getting browser: ie, but was suppressed with fallback.
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <link href="https://gmpg.org/xfn/11" rel="profile"/>
#    <script src="https://cmp.osano.com/16A1AnRt2Fn8i1unj/f15ebf08-7008-40fe-9af3-db96dc3e8266/osano.js">
#    </script>
#    <title>
#     Chicago’s 50 Best Restaurants, Ranked – Chicago Magazine
#    </title>
#    <style type="text/css">
#     .heateor_sss_button_instagram span.heateor_sss_svg,a.heateor_sss_instagram span.heateor_sss_svg{background:radial-gradient(circle at 30% 107%,#fdf497 0,#fdf497 5%,#fd5949 45%,#d6249f 60%,#285aeb 90%)}
# 						div.heateor_sss_horizontal_sharing a.heateor_sss_button_instagram span{background:#000!important;}div.heateor_sss_standard_follow_icons_container a.heateor_sss_button_instagram span{background:#000;}
# ...

# %% [markdown]
# <a id="restaurants-50-list"></a>
# ### 식당 50개 정보 추출

# %%
# soup.find_all("a", class_="br50-link"), len(soup.find_all("a", class_="br50-link")) 
soup.select("a.br50-link"), len(soup.select("a.br50-link"))
# Out:
# ([<a class="br50-link price-3" href="/chicago-magazine/august-2024/50-best-restaurants/monteverde/">
#   <div class="br50-img br50-1" style="background-image: url('https://www.chicagomag.com/wp-content/uploads/2024/06/monteverde-1.jpg');"></div> <h2><span>1</span>Monteverde</h2>
#   <h3>
#   			West Loop<br/>
#   <span>$$$<span class="light">$$</span></span>
#   </h3>
#   </a>,
#   <a class="br50-link price-5" href="/chicago-magazine/august-2024/50-best-restaurants/oriole/">
#   <h2><span>2</span>Oriole</h2>
#   <h3>
#   			West Loop<br/>
#   <span>$$$$$</span>
#   </h3>
#   </a>,
#   <a class="br50-link price-4" href="/chicago-magazine/august-2024/50-best-restaurants/galit/">
#   <h2><span>3</span>Galit</h2>
#   <h3>
#   			Lincoln Park<br/>
#   <span>$$$$<span class="light">$</span></span>
#   </h3>
#   </a>,
#   <a class="br50-link price-3" href="/chicago-magazine/august-2024/50-best-restaurants/avec/">
#   <h2><span>4</span>Avec</h2>
#   <h3>
#   			West Loop | River North<br/>
# ...

# %% [markdown]
# #### 식당 태그 확인

# %%
restaurant_one = soup.select("a.br50-link")[0]
restaurant_one
# Out:
# <a class="br50-link price-3" href="/chicago-magazine/august-2024/50-best-restaurants/monteverde/">
# <div class="br50-img br50-1" style="background-image: url('https://www.chicagomag.com/wp-content/uploads/2024/06/monteverde-1.jpg');"></div> <h2><span>1</span>Monteverde</h2>
# <h3>
# 			West Loop<br/>
# <span>$$$<span class="light">$$</span></span>
# </h3>
# </a>

# %%
# 순위

# restaurant_one.find("h2").find("span").get_text()
restaurant_one.select_one("h2 > span").text
# Out:
# '1'

# %%
# 동네

# restaurant_one.find("h3").get_text()
restaurant_one.select_one("h3").text
# Out:
# '\r\n\t\t\tWest Loop\n$$$$$\n'

# %%
# 링크

restaurant_one["href"]
# Out:
# '/chicago-magazine/august-2024/50-best-restaurants/monteverde/'

# %%
# 가게 이름

restaurant_one.select_one("h2").text[1:]
# Out:
# 'Monteverde'

# %%
# 동네 데이터가 문자만 출력되는 것이 아니라 re의 split 기능을 이용

import re

neighborhood = restaurant_one.find("h3").get_text()
re.split(("\n|\r\n|\t"), neighborhood)[4]
# Out:
# 'West Loop'

# %% [markdown]
# #### 데이터프레임으로 변환

# %%
import re
from urllib.parse import urljoin

url_base = "https://www.chicagomag.com/"

restaurant_tags = soup.select("a.br50-link")
rank = []
neighborhood = []
name = []
link = []

for tag in restaurant_tags:

    rank.append(tag.select_one("h2 > span").text)
    neighborhood.append(re.split(("\n|\r\n|\t"), tag.find("h3").get_text())[4])
    name.append(tag.select_one("h2").text[1:])
    link.append(urljoin(url_base, tag["href"]))

len(rank), len(neighborhood), len(name), len(link)
# Out:
# (50, 50, 50, 50)

# %%
data = {
    'Rank': rank,
    'Neighborhood': neighborhood, 
    'Name': name,
    'URL': link
}

df = pd.DataFrame(data)
df.tail()
# Out:
#    Rank                           Neighborhood                        Name  \
# 45   46                            River North           6Shanghai Terrace
# 46   47                              Hyde Park  7Daisy’s Po-Boy and Tavern
# 47   48                              Chinatown    8Dolo Restaurant and Bar
# 48   49  Lake View | Logan Square | Bridgeport               9Redhot Ranch
# 49   50                                 Uptown         0Immm Rice & Beyond
#
#                                                   URL
# 45  https://www.chicagomag.com/chicago-magazine/au...
# 46  https://www.chicagomag.com/chicago-magazine/au...
# 47  https://www.chicagomag.com/chicago-magazine/au...
# 48  https://www.chicagomag.com/chicago-magazine/au...
# 49  https://www.chicagomag.com/chicago-magazine/au...

# %%
# 컬럼 순서 변경

df = pd.DataFrame(data, columns=["Rank", "Name", "Neighborhood", "URL"])
df.tail()
# Out:
#    Rank                        Name                           Neighborhood  \
# 45   46           6Shanghai Terrace                            River North
# 46   47  7Daisy’s Po-Boy and Tavern                              Hyde Park
# 47   48    8Dolo Restaurant and Bar                              Chinatown
# 48   49               9Redhot Ranch  Lake View | Logan Square | Bridgeport
# 49   50         0Immm Rice & Beyond                                 Uptown
#
#                                                   URL
# 45  https://www.chicagomag.com/chicago-magazine/au...
# 46  https://www.chicagomag.com/chicago-magazine/au...
# 47  https://www.chicagomag.com/chicago-magazine/au...
# 48  https://www.chicagomag.com/chicago-magazine/au...
# 49  https://www.chicagomag.com/chicago-magazine/au...

# %% [markdown]
# #### 데이터 저장

# %%
df.to_csv(
    "../data/03. best_restaurants_list_chicago.csv", sep=",", encoding="utf-8"
)

# %% [markdown]
# ---

# %% [markdown]
# <a id="하위"></a>
# ## 4. 시카고 맛집 데이터 분석 - 하위페이지

# %%
# requirements
import pandas as pd
from urllib.request import urlopen, Request
from fake_useragent import UserAgent
from bs4 import BeautifulSoup

# %%
df = pd.read_csv("../data/03. best_restaurants_list_chicago.csv", index_col=0)
df.tail()
# Out:
#     Rank                        Name                           Neighborhood  \
# 45    46           6Shanghai Terrace                            River North
# 46    47  7Daisy’s Po-Boy and Tavern                              Hyde Park
# 47    48    8Dolo Restaurant and Bar                              Chinatown
# 48    49               9Redhot Ranch  Lake View | Logan Square | Bridgeport
# 49    50         0Immm Rice & Beyond                                 Uptown
#
#                                                   URL
# 45  https://www.chicagomag.com/chicago-magazine/au...
# 46  https://www.chicagomag.com/chicago-magazine/au...
# 47  https://www.chicagomag.com/chicago-magazine/au...
# 48  https://www.chicagomag.com/chicago-magazine/au...
# 49  https://www.chicagomag.com/chicago-magazine/au...

# %% [markdown]
# <a id="rank1-하위"></a>
# ### rank 1 식당 하위 페이지 html 가져오기

# %%
req = Request(df["URL"][0], headers={"User-Agent": UserAgent().ie})
html = urlopen(req).read()
soup_tmp = BeautifulSoup(html, "html.parser")
soup_tmp.find(class_="br50-footer")
# Out:
# Error occurred during getting browser: ie, but was suppressed with fallback.
# <div class="br50-footer">
# <p>
# <strong>Price:</strong>
# <span class="dollars">$$$<span class="light">$$</span></span><br/>
# <strong>Address:</strong> 1020 W. Madison St.<br/>
# <strong>Website:</strong> <a href="https://monteverdechicago.com" target="_blank">monteverdechicago.com</a>
# </p>
# </div>

# %%
details = soup_tmp.find_all("strong")
details
# Out:
# [<strong>Price:</strong>, <strong>Address:</strong>, <strong>Website:</strong>]

# %%
# price 추출

price_levels = ['매우 저렴', '저렴', '보통', '비쌈', '매우 비쌈']
price_level = len(price_levels) - len(details[0].find_next_sibling().find(class_="light").text)
price_level_str = price_levels[price_level-1]

price_level, price_level_str
# Out:
# (3, '보통')

# %%
# address 추출

address = details[1].next_sibling.strip()
address
# Out:
# '1020 W. Madison St.'

# %%
# website 추출

website = details[2].find_next_sibling().text
website
# Out:
# 'monteverdechicago.com'

# %% [markdown]
# <a id="하위페이지s"></a>
# ### 50개의 식당 하위 페이지에서 식당 정보 수집

# %% [markdown]
# #### tqdm
# - conda install conda-forge::tqdm
#
# for 문 progress bar를 보여준다.

# %%
from tqdm import tqdm

price = []
price_level = []
address = []
website = []

price_levels = ['매우 저렴', '저렴', '보통', '비쌈', '매우 비쌈']

for idx, row in tqdm(df.iterrows(), total=len(df)):
    req = Request(row["URL"], headers={"User-Agent": UserAgent().ie})
    html = urlopen(req).read()
    soup_tmp = BeautifulSoup(html, "html.parser")
    soup_tmp.find(class_="br50-footer")

    details = soup_tmp.find_all("strong")

    level_tmp = details[0].find_next_sibling().find(class_="light")    
    price_level.append(len(price_levels) - (len(level_tmp.text) if level_tmp != None else 0))
    price.append(price_levels[price_level[-1]-1])

    address.append(details[1].next_sibling.strip())
    website.append(details[2].find_next_sibling().text)

len(price), len(price_level), len(address), len(website)
# Out:
# ...
# 100%|███████████████████████████████████████████| 50/50 [01:36<00:00,  1.93s/it]
# (50, 50, 50, 50)

# %%
df["Price"] = price
df["Price Level"]  = price_level
df["Address"] = address
df["Website"] = website
df.head()
# Out:
#    Rank        Name             Neighborhood  \
# 0     1  Monteverde                West Loop
# 1     2      Oriole                West Loop
# 2     3       Galit             Lincoln Park
# 3     4        Avec  West Loop | River North
# 4     5      Kasama   East Ukrainian Village
#
#                                                  URL  Price  Price Level  \
# 0  https://www.chicagomag.com/chicago-magazine/au...     보통            3
# 1  https://www.chicagomag.com/chicago-magazine/au...  매우 비쌈            5
# 2  https://www.chicagomag.com/chicago-magazine/au...     비쌈            4
# 3  https://www.chicagomag.com/chicago-magazine/au...     보통            3
# 4  https://www.chicagomag.com/chicago-magazine/au...  매우 비쌈            5
#
#                                  Address                  Website
# 0                    1020 W. Madison St.    monteverdechicago.com
# 1                      661 W. Walnut St.    www.oriolechicago.com
# ...

# %%
df.set_index("Rank", inplace=True)
df.head()
# Out:
#             Name             Neighborhood  \
# Rank
# 1     Monteverde                West Loop
# 2         Oriole                West Loop
# 3          Galit             Lincoln Park
# 4           Avec  West Loop | River North
# 5         Kasama   East Ukrainian Village
#
#                                                     URL  Price  Price Level  \
# Rank
# 1     https://www.chicagomag.com/chicago-magazine/au...     보통            3
# 2     https://www.chicagomag.com/chicago-magazine/au...  매우 비쌈            5
# 3     https://www.chicagomag.com/chicago-magazine/au...     비쌈            4
# 4     https://www.chicagomag.com/chicago-magazine/au...     보통            3
# 5     https://www.chicagomag.com/chicago-magazine/au...  매우 비쌈            5
#
#                                     Address                  Website
# Rank
# 1                       1020 W. Madison St.    monteverdechicago.com
# 2                         661 W. Walnut St.    www.oriolechicago.com
# ...

# %%
# URL 은 이제 필요없으므로 제거
df.drop(columns=["URL"], inplace=True)
df.head()
# Out:
#             Name             Neighborhood  Price  Price Level  \
# Rank
# 1     Monteverde                West Loop     보통            3
# 2         Oriole                West Loop  매우 비쌈            5
# 3          Galit             Lincoln Park     비쌈            4
# 4           Avec  West Loop | River North     보통            3
# 5         Kasama   East Ukrainian Village  매우 비쌈            5
#
#                                     Address                  Website
# Rank
# 1                       1020 W. Madison St.    monteverdechicago.com
# 2                         661 W. Walnut St.    www.oriolechicago.com
# 3                      2429 N. Lincoln Ave.  www.galitrestaurant.com
# 4     615 W. Randolph St. | 141 W. Erie St.   www.avecrestaurant.com
# 5                   1001 N. Winchester Ave.    www.kasamachicago.com

# %% [markdown]
# #### 데이터 저장

# %%
df.to_csv(
    "../data/03. best_restaurants_list_chicago2.csv", 
    sep=",",
    encoding="utf-8"
)

# %%
pd.read_csv("../data/03. best_restaurants_list_chicago2.csv", index_col=0).head()
# Out:
#             Name             Neighborhood  Price  Price Level  \
# Rank
# 1     Monteverde                West Loop     보통            3
# 2         Oriole                West Loop  매우 비쌈            5
# 3          Galit             Lincoln Park     비쌈            4
# 4           Avec  West Loop | River North     보통            3
# 5         Kasama   East Ukrainian Village  매우 비쌈            5
#
#                                     Address                  Website
# Rank
# 1                       1020 W. Madison St.    monteverdechicago.com
# 2                         661 W. Walnut St.    www.oriolechicago.com
# 3                      2429 N. Lincoln Ave.  www.galitrestaurant.com
# 4     615 W. Randolph St. | 141 W. Erie St.   www.avecrestaurant.com
# 5                   1001 N. Winchester Ave.    www.kasamachicago.com

# %% [markdown]
# ---

# %% [markdown]
# <a id="정규표현식"></a>
# ## 정규표현식 예제

# %%
req = Request("https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Publican-Quality-Meats-PB-L/", headers={"user-agent":ua.ie})
html = urlopen(req).read()
soup_tmp = BeautifulSoup(html, "html.parser")
soup_tmp.find("p", "addy") # soup_find.select_one(".addy")
# Out:
# Error occurred during getting browser: ie, but was suppressed with fallback.
# <p class="addy">
# <em>$10. 825 W. Fulton Mkt., 312-445-8977, <a href="http://publicanqualitymeats.com/">publicanqualitymeats.com</a></em></p>

# %%
price_temp = soup_tmp.find("p", "addy").text
price_temp
# Out:
# '\n$10. 825 W. Fulton Mkt., 312-445-8977, publicanqualitymeats.com'

# %%
import re
re.split(".,", price_temp)
# Out:
# ['\n$10. 825 W. Fulton Mkt', ' 312-445-897', ' publicanqualitymeats.com']

# %%
price_temp = re.split(".,", price_temp)[0]
price_temp
# Out:
# '\n$10. 825 W. Fulton Mkt'

# %%
price_re = re.search("\$\d+\.(\d+)?", price_temp).group()
address_re = price_temp[len(price_re)+2:]

price_re, address_re
# Out:
# ('$10.', '825 W. Fulton Mkt')

# %% [markdown]
# ---

# %% [markdown]
# <a id="folium"></a>
# ## 5. 시카고 맛집 데이터 지도 시각화

# %%
import googlemaps
import folium
import pandas as pd
from dotenv import load_dotenv
import os
from tqdm import tqdm

load_dotenv('.env')
gmaps_key = os.environ.get('GCP_API_KEY')
gmaps = googlemaps.Client(key=gmaps_key)

# %%
df = pd.read_csv("../data/03. best_restaurants_list_chicago2.csv", index_col=0)
df
# Out:
#                                  Name                           Neighborhood  \
# Rank
# 1                          Monteverde                              West Loop
# 2                              Oriole                              West Loop
# 3                               Galit                           Lincoln Park
# 4                                Avec                West Loop | River North
# 5                              Kasama                 East Ukrainian Village
# 6                              Virtue                              Hyde Park
# 7          HaiSous Vietnamese Kitchen                                 Pilsen
# 8                   Shaw’s Crab House                            River North
# 9                       Dear Margaret                              Lake View
# 10                              0Boka                           Lincoln Park
# 11           1Kyoten/Kyoten Next Door                           Logan Square
# ...

# %%
for idx, row in df[:1].iterrows():
    target_name = row["Address"] + ", Chicago"
    gmaps_output = gmaps.geocode(target_name)
    print(gmaps_output)
    print(len(gmaps_output))
    print(gmaps_output[0]['geometry'])
    print(gmaps_output[0]['geometry']['location'])
# Out:
# [{'address_components': [{'long_name': '1020', 'short_name': '1020', 'types': ['street_number']}, {'long_name': 'West Madison Street', 'short_name': 'W Madison St', 'types': ['route']}, {'long_name': 'West Loop', 'short_name': 'West Loop', 'types': ['neighborhood', 'political']}, {'long_name': 'Chicago', 'short_name': 'Chicago', 'types': ['locality', 'political']}, {'long_name': 'Cook County', 'short_name': 'Cook County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Illinois', 'short_name': 'IL', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '60607', 'short_name': '60607', 'types': ['postal_code']}, {'long_name': '2008', 'short_name': '2008', 'types': ['postal_code_suffix']}], 'formatted_address': '1020 W Madison St, Chicago, IL 60607, USA', 'geometry': {'location': {'lat': 41.8819188, 'lng': -87.6529673}, 'location_type': 'ROOFTOP', 'viewport': {'n
# ...

# %%
lat = []
lng = []

for idx, row in tqdm(df.iterrows(), total=len(df)):
    target_name = row["Address"] + ", Chicago"
    gmaps_output = gmaps.geocode(target_name)
    lat.append(gmaps_output[0]['geometry']['location']['lat'])
    lng.append(gmaps_output[0]['geometry']['location']['lng'])

df['lat'] = lat
df['lng'] = lng
df
# Out:
# 100%|███████████████████████████████████████████| 50/50 [00:07<00:00,  6.34it/s]
#                                  Name                           Neighborhood  \
# Rank
# 1                          Monteverde                              West Loop
# 2                              Oriole                              West Loop
# 3                               Galit                           Lincoln Park
# 4                                Avec                West Loop | River North
# 5                              Kasama                 East Ukrainian Village
# 6                              Virtue                              Hyde Park
# 7          HaiSous Vietnamese Kitchen                                 Pilsen
# 8                   Shaw’s Crab House                            River North
# 9                       Dear Margaret                              Lake View
# 10                              0Boka                           Lincoln Park
# ...

# %%
mapping = folium.Map(location=[41.8781136, -87.6297982], zoom_start=11)

for idx, row in df.iterrows():
    folium.Marker(
        location=[row["lat"], row["lng"]],
        popup=row["Name"],
        tooltip=row["Neighborhood"],
        icon=folium.Icon(
            icon="smile",
            prefix="fa"
        )
    ).add_to(mapping)

mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
